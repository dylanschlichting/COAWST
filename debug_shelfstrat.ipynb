# %%
import xarray as xr
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# # Open shelfstrat basecase

# %%
ds = xr.open_dataset('/scratch/user/dylan.schlichting/COAWST/Projects/shelfstrat/runs/shelf_ho_5_dh_0_dx_1000_avg.nc')
ds

# %%
ds = xr.open_dataset('/scratch/user/dylan.schlichting/COAWST/Projects/shelfstrat/runs/shelf_ho_5_dh_0_dx_1000_avg.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (tracer: 2, s_rho: 30, s_w: 31, Nuser: 25, eta_rho: 130, xi_rho: 258, eta_u: 130, xi_u: 257, eta_v: 129, xi_v: 258, eta_psi: 129, xi_psi: 257, ocean_time: 5)
# Coordinates:
#   * s_rho           (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w             (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#     x_rho           (eta_rho, xi_rho) float64 ...
#     y_rho           (eta_rho, xi_rho) float64 ...
#     x_u             (eta_u, xi_u) float64 ...
#     y_u             (eta_u, xi_u) float64 ...
#     x_v             (eta_v, xi_v) float64 ...
#     y_v             (eta_v, xi_v) float64 ...
#   * ocean_time      (ocean_time) object 0001-01-05 00:30:00 ... 0001-01-05 04...
# Dimensions without coordinates: tracer, Nuser, eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi
# Data variables: (12/95)
#     ntimes          int32 ...
#     ndtfast         int32 ...
#     dt              float64 ...
# ...

# %%
ds.dye_03_02
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 ds.dye_03_02
#
# NameError: name 'ds' is not defined

# %%
ds.dt
# Out:
# <xarray.DataArray 'dt' ()>
# array(30.)
# Attributes:
#     long_name:  size of long time-steps
#     units:      second

# %%
ds = xr.open_dataset('/scratch/user/dylan.schlichting/COAWST/Projects/shelfstrat/runs/shelf_ho_5_dh_0_dx_1000_grd.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (eta_vert: 131, xi_vert: 259, eta_rho: 130, xi_rho: 258, eta_psi: 129, xi_psi: 257, eta_u: 130, xi_u: 257, eta_v: 129, xi_v: 258)
# Dimensions without coordinates: eta_vert, xi_vert, eta_rho, xi_rho, eta_psi, xi_psi, eta_u, xi_u, eta_v, xi_v
# Data variables: (12/18)
#     x_vert     (eta_vert, xi_vert) float64 ...
#     y_vert     (eta_vert, xi_vert) float64 ...
#     x_rho      (eta_rho, xi_rho) float64 ...
#     y_rho      (eta_rho, xi_rho) float64 ...
#     x_psi      (eta_psi, xi_psi) float64 ...
#     y_psi      (eta_psi, xi_psi) float64 ...
#     ...         ...
#     xl         int64 ...
#     el         int64 ...
#     spherical  bool ...
#     f          (eta_rho, xi_rho) float64 ...
#     angle      (eta_rho, xi_rho) float64 ...
#     h          (eta_rho, xi_rho) float64 ...
